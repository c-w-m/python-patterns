# %% [markdown]
# # Tox Prototype
#
# Before running [`tox.ini`](../tox.ini) with a matrix of tests vs Python versions it is wise to manually run the same testing in your development environment.
#
# ## Development Environment
#
# The recommended development (__dev__) environment:
#
# - Python 3.10
# - requirements_dev.txt   # must have, accounts for every possibility
# - requirements_user.txt  # nice to have
# - test_requirements.txt  # benchmark (do this from tox)
#
# > Note: The [`Dockerfile`](../.devcontainer/Dockerfile) loads all three of these `requirements` files into the [`devcontianer`](../.devcontainer/devcontainer.json).

# %% [markdown]
# ---
#
# ## [`tox.ini`](../tox.ini)
#
# This is a 'developers' version with the following perspective:
#
# - py39 only
#   - use this notebook to manually check py310
#   - no plan to support py38 or earlier
#
# ---
#
# ## Test: `pytest` and `coverage`
#
# __[testenv]__
#
# Looking for broken code to the extent necessary for development.
#
# Minimal Requirements:
#
# - fix all broken tests
# - create new tests to cover new behavior
# - maintain ~40% at all times during development

# %%
# versions used for testing ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! python --version
! coverage --version
! pytest --version
# Out:
# Python 3.10.4
# Coverage.py, version 6.3.2 with C extension
# Full documentation is at https://coverage.readthedocs.io
# pytest 6.2.5

# %%
# pytest only ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && pytest tests
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.4, pytest-6.2.5, py-1.11.0, pluggy-1.0.0
# Using --randomly-seed=1650664288
# rootdir: /workspaces/python-patterns, configfile: setup.cfg
# plugins: anyio-3.5.0, cov-2.11.1, randomly-3.1.0
# collected 65 items
#
# tests/behavioral/test_state.py ...                                       [  4%]
# tests/structural/test_proxy.py ..                                        [  7%]
# tests/structural/test_decorator.py ...                                   [ 12%]
# tests/structural/test_adapter.py ..........                              [ 27%]
# tests/creational/test_borg.py ...                                        [ 32%]
# tests/creational/test_builder.py ...                                     [ 36%]
# tests/creational/test_abstract_factory.py .                              [ 38%]
# tests/test_hsm.py ...........                                            [ 55%]
# tests/creational/test_lazy.py .....                                      [ 63%]
# tests/creational/test_pool.py ...                                        [ 67%]
# tests/behavioral/test_observer.py ..                                     [ 70%]
# tests/behavioral/test_publish_subscribe.py ....                          [ 76%]
# tests/creational/test_prototype.py ......                                [ 86%]
# tests/behavioral/test_strategy.py .......                                [ 96%]
# tests/structural/test_bridge.py ..                                       [100%]
#
# ============================== 65 passed in 0.88s ==============================

# %%
# pytest and coverage ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && pytest --cov
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.4, pytest-6.2.5, py-1.11.0, pluggy-1.0.0
# Using --randomly-seed=1650664290
# rootdir: /workspaces/python-patterns, configfile: setup.cfg
# plugins: anyio-3.5.0, cov-2.11.1, randomly-3.1.0
# collected 65 items
#
# tests/test_hsm.py ...........                                            [ 16%]
# tests/behavioral/test_observer.py ..                                     [ 20%]
# tests/structural/test_adapter.py ..........                              [ 35%]
# tests/behavioral/test_publish_subscribe.py ....                          [ 41%]
# tests/behavioral/test_strategy.py .......                                [ 52%]
# tests/creational/test_pool.py ...                                        [ 56%]
# tests/structural/test_proxy.py ..                                        [ 60%]
# tests/behavioral/test_state.py ...                                       [ 64%]
# tests/structural/test_bridge.py ..                                       [ 67%]
# tests/creational/test_lazy.py .....                                      [ 75%]
# tests/creational/test_borg.py ...                                        [ 80%]
# tests/creational/test_builder.py ...                                     [ 84%]
# tests/structural/test_decorator.py ...                                   [ 89%]
# tests/creational/test_abstract_factory.py .                              [ 90%]
# tests/creational/test_prototype.py ......                                [100%]
#
# ---------- coverage: platform linux, python 3.10.4-final-0 -----------
# Name                                         Stmts   Miss  Cover
# ----------------------------------------------------------------
# patterns/__init__.py                             0      0   100%
# patterns/behavioral/__init__.py                  0      0   100%
# patterns/behavioral/observer.py                 41      4    90%
# patterns/behavioral/publish_subscribe.py        34      3    91%
# patterns/behavioral/state.py                    37      7    81%
# patterns/behavioral/strategy.py                 40      4    90%
# patterns/creational/__init__.py                  0      0   100%
# patterns/creational/abstract_factory.py         31      7    77%
# patterns/creational/borg.py                     18      4    78%
# patterns/creational/builder.py                  35      4    89%
# patterns/creational/lazy_evaluation.py          36      3    92%
# patterns/creational/pool.py                     20      4    80%
# patterns/creational/prototype.py                23      3    87%
# patterns/other/__init__.py                       0      0   100%
# patterns/other/hsm/__init__.py                   0      0   100%
# patterns/other/hsm/hsm.py                      106     24    77%
# patterns/structural/__init__.py                  0      0   100%
# patterns/structural/adapter.py                  34      4    88%
# patterns/structural/bridge.py                   20      4    80%
# patterns/structural/decorator.py                19      2    89%
# patterns/structural/proxy.py                    20      2    90%
# tests/behavioral/test_observer.py               20      0   100%
# tests/behavioral/test_publish_subscribe.py      51      0   100%
# tests/behavioral/test_state.py                  16      0   100%
# tests/behavioral/test_strategy.py               20      0   100%
# tests/creational/test_abstract_factory.py       10      0   100%
# tests/creational/test_borg.py                   19      0   100%
# tests/creational/test_builder.py                16      0   100%
# tests/creational/test_lazy.py                   19      0   100%
# tests/creational/test_pool.py                   32      0   100%
# tests/creational/test_prototype.py              37      0   100%
# tests/structural/test_adapter.py                59      0   100%
# tests/structural/test_bridge.py                 33      0   100%
# tests/structural/test_decorator.py              11      0   100%
# tests/structural/test_proxy.py                  21      0   100%
# tests/test_hsm.py                               55      0   100%
# ----------------------------------------------------------------
# TOTAL                                          933     79    92%
#
#
# ============================== 65 passed in 3.27s ==============================

# %% [markdown]
# ---
#
# ## Linters: `flake8`, `isort`, `black`, and `twine`
#
# __[testenv:linters]__
#
# Lint - Readability and style enforcement.
#
# Minimal Requirements:
#
# - fix all warnings

# %%
# versions used for testing ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! python --version
! flake8 --version
! isort --version
! black --version
! twine --version
# Out:
# Python 3.10.4
# 3.8.4 (mccabe: 0.6.1, pycodestyle: 2.6.0, pyflakes: 2.2.0) CPython 3.10.4 on
# Linux
#
#                  _                 _
#                 (_) ___  ___  _ __| |_
#                 | |/ _/ / _ \/ '__  _/
#                 | |\__ \/\_\/| |  | |_
#                 |_|\___/\___/\_/   \_/
#
#       isort your imports, so you don't have to.
#
#                     VERSION 5.7.0
#
# black, 22.3.0 (compiled: yes)
# /bin/bash: line 1: twine: command not found

# %% [markdown]
# ---
#
# ### `flake8`

# %%
# flake8 all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 patterns tests setup.py

# %%
# flake8 patterns ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 patterns

# %%
# flake8 tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 tests

# %%
# flake8 setup ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && flake8 setup.py

# %% [markdown]
# ---
#
# ### `isort`

# %%
# isort all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df patterns tests setup.py
# Out:
# ERROR: /workspaces/python-patterns/patterns/behavioral/memento.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/patterns/behavioral/memento.py:before	2022-04-22 21:28:56.831495
# +++ /workspaces/python-patterns/patterns/behavioral/memento.py:after	2022-04-22 21:51:37.918687
# @@ -5,8 +5,8 @@
#  Provides the ability to restore an object to its previous state.
#  """
#
# +from copy import copy, deepcopy
#  from typing import Callable, List
# -from copy import copy, deepcopy
#
#
#  def memento(obj, deep=False):
# ERROR: /workspaces/python-patterns/tests/test_hsm.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/test_hsm.py:before	2022-04-22 21:28:57.146295
# +++ /workspaces/python-patterns/tests/test_hsm.py:after	2022-04-22 21:51:39.044161
# @@ -1,15 +1,9 @@
#  import unittest
#  from unittest.mock import patch
#
# -from patterns.other.hsm.hsm import (
# -    Active,
# -    HierachicalStateMachine,
# -    Standby,
# -    Suspect,
# -    UnsupportedMessageType,
# -    UnsupportedState,
# -    UnsupportedTransition,
# -)
# +from patterns.other.hsm.hsm import (Active, HierachicalStateMachine, Standby,
# +                                    Suspect, UnsupportedMessageType,
# +                                    UnsupportedState, UnsupportedTransition)
#
#
#  class HsmMethodTest(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:before	2022-04-22 21:28:57.115046
# +++ /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:after	2022-04-22 21:51:39.106418
# @@ -1,7 +1,8 @@
#  import unittest
#  from unittest.mock import call, patch
#
# -from patterns.behavioral.publish_subscribe import Provider, Publisher, Subscriber
# +from patterns.behavioral.publish_subscribe import (Provider, Publisher,
# +                                                   Subscriber)
#
#
#  class TestProvider(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_strategy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_strategy.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/behavioral/test_strategy.py:after	2022-04-22 21:51:39.149781
# @@ -1,6 +1,7 @@
#  import pytest
#
# -from patterns.behavioral.strategy import Order, ten_percent_discount, on_sale_discount
# +from patterns.behavioral.strategy import (Order, on_sale_discount,
# +                                          ten_percent_discount)
#
#
#  @pytest.fixture
# ERROR: /workspaces/python-patterns/tests/creational/test_builder.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/creational/test_builder.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/creational/test_builder.py:after	2022-04-22 21:51:39.264334
# @@ -1,6 +1,7 @@
#  import unittest
#
# -from patterns.creational.builder import ComplexHouse, Flat, House, construct_building
# +from patterns.creational.builder import (ComplexHouse, Flat, House,
# +                                         construct_building)
#
#
#  class TestSimple(unittest.TestCase):

# %%
# isort patterns ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df patterns
# Out:
# ERROR: /workspaces/python-patterns/patterns/behavioral/memento.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/patterns/behavioral/memento.py:before	2022-04-22 21:28:56.831495
# +++ /workspaces/python-patterns/patterns/behavioral/memento.py:after	2022-04-22 21:51:40.136137
# @@ -5,8 +5,8 @@
#  Provides the ability to restore an object to its previous state.
#  """
#
# +from copy import copy, deepcopy
#  from typing import Callable, List
# -from copy import copy, deepcopy
#
#
#  def memento(obj, deep=False):

# %%
# isort tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df tests
# Out:
# ERROR: /workspaces/python-patterns/tests/test_hsm.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/test_hsm.py:before	2022-04-22 21:28:57.146295
# +++ /workspaces/python-patterns/tests/test_hsm.py:after	2022-04-22 21:51:41.559208
# @@ -1,15 +1,9 @@
#  import unittest
#  from unittest.mock import patch
#
# -from patterns.other.hsm.hsm import (
# -    Active,
# -    HierachicalStateMachine,
# -    Standby,
# -    Suspect,
# -    UnsupportedMessageType,
# -    UnsupportedState,
# -    UnsupportedTransition,
# -)
# +from patterns.other.hsm.hsm import (Active, HierachicalStateMachine, Standby,
# +                                    Suspect, UnsupportedMessageType,
# +                                    UnsupportedState, UnsupportedTransition)
#
#
#  class HsmMethodTest(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:before	2022-04-22 21:28:57.115046
# +++ /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:after	2022-04-22 21:51:41.618312
# @@ -1,7 +1,8 @@
#  import unittest
#  from unittest.mock import call, patch
#
# -from patterns.behavioral.publish_subscribe import Provider, Publisher, Subscriber
# +from patterns.behavioral.publish_subscribe import (Provider, Publisher,
# +                                                   Subscriber)
#
#
#  class TestProvider(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_strategy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_strategy.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/behavioral/test_strategy.py:after	2022-04-22 21:51:41.664065
# @@ -1,6 +1,7 @@
#  import pytest
#
# -from patterns.behavioral.strategy import Order, ten_percent_discount, on_sale_discount
# +from patterns.behavioral.strategy import (Order, on_sale_discount,
# +                                          ten_percent_discount)
#
#
#  @pytest.fixture
# ERROR: /workspaces/python-patterns/tests/creational/test_builder.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/creational/test_builder.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/creational/test_builder.py:after	2022-04-22 21:51:41.770882
# @@ -1,6 +1,7 @@
#  import unittest
#
# -from patterns.creational.builder import ComplexHouse, Flat, House, construct_building
# +from patterns.creational.builder import (ComplexHouse, Flat, House,
# +                                         construct_building)
#
#
#  class TestSimple(unittest.TestCase):

# %%
# isort setup ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df setup.py

# %% [markdown]
# ---
#
# ### `black`

# %%
# isort all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df patterns tests setup.py
# Out:
# ERROR: /workspaces/python-patterns/patterns/behavioral/memento.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/patterns/behavioral/memento.py:before	2022-04-22 21:28:56.831495
# +++ /workspaces/python-patterns/patterns/behavioral/memento.py:after	2022-04-22 21:51:43.034997
# @@ -5,8 +5,8 @@
#  Provides the ability to restore an object to its previous state.
#  """
#
# +from copy import copy, deepcopy
#  from typing import Callable, List
# -from copy import copy, deepcopy
#
#
#  def memento(obj, deep=False):
# ERROR: /workspaces/python-patterns/tests/test_hsm.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/test_hsm.py:before	2022-04-22 21:28:57.146295
# +++ /workspaces/python-patterns/tests/test_hsm.py:after	2022-04-22 21:51:44.032887
# @@ -1,15 +1,9 @@
#  import unittest
#  from unittest.mock import patch
#
# -from patterns.other.hsm.hsm import (
# -    Active,
# -    HierachicalStateMachine,
# -    Standby,
# -    Suspect,
# -    UnsupportedMessageType,
# -    UnsupportedState,
# -    UnsupportedTransition,
# -)
# +from patterns.other.hsm.hsm import (Active, HierachicalStateMachine, Standby,
# +                                    Suspect, UnsupportedMessageType,
# +                                    UnsupportedState, UnsupportedTransition)
#
#
#  class HsmMethodTest(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:before	2022-04-22 21:28:57.115046
# +++ /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:after	2022-04-22 21:51:44.094732
# @@ -1,7 +1,8 @@
#  import unittest
#  from unittest.mock import call, patch
#
# -from patterns.behavioral.publish_subscribe import Provider, Publisher, Subscriber
# +from patterns.behavioral.publish_subscribe import (Provider, Publisher,
# +                                                   Subscriber)
#
#
#  class TestProvider(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_strategy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_strategy.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/behavioral/test_strategy.py:after	2022-04-22 21:51:44.135072
# @@ -1,6 +1,7 @@
#  import pytest
#
# -from patterns.behavioral.strategy import Order, ten_percent_discount, on_sale_discount
# +from patterns.behavioral.strategy import (Order, on_sale_discount,
# +                                          ten_percent_discount)
#
#
#  @pytest.fixture
# ERROR: /workspaces/python-patterns/tests/creational/test_builder.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/creational/test_builder.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/creational/test_builder.py:after	2022-04-22 21:51:44.258570
# @@ -1,6 +1,7 @@
#  import unittest
#
# -from patterns.creational.builder import ComplexHouse, Flat, House, construct_building
# +from patterns.creational.builder import (ComplexHouse, Flat, House,
# +                                         construct_building)
#
#
#  class TestSimple(unittest.TestCase):

# %%
# isort patterns ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df patterns
# Out:
# ERROR: /workspaces/python-patterns/patterns/behavioral/memento.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/patterns/behavioral/memento.py:before	2022-04-22 21:28:56.831495
# +++ /workspaces/python-patterns/patterns/behavioral/memento.py:after	2022-04-22 21:51:45.117657
# @@ -5,8 +5,8 @@
#  Provides the ability to restore an object to its previous state.
#  """
#
# +from copy import copy, deepcopy
#  from typing import Callable, List
# -from copy import copy, deepcopy
#
#
#  def memento(obj, deep=False):

# %%
# isort tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df tests
# Out:
# ERROR: /workspaces/python-patterns/tests/test_hsm.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/test_hsm.py:before	2022-04-22 21:28:57.146295
# +++ /workspaces/python-patterns/tests/test_hsm.py:after	2022-04-22 21:51:46.566640
# @@ -1,15 +1,9 @@
#  import unittest
#  from unittest.mock import patch
#
# -from patterns.other.hsm.hsm import (
# -    Active,
# -    HierachicalStateMachine,
# -    Standby,
# -    Suspect,
# -    UnsupportedMessageType,
# -    UnsupportedState,
# -    UnsupportedTransition,
# -)
# +from patterns.other.hsm.hsm import (Active, HierachicalStateMachine, Standby,
# +                                    Suspect, UnsupportedMessageType,
# +                                    UnsupportedState, UnsupportedTransition)
#
#
#  class HsmMethodTest(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:before	2022-04-22 21:28:57.115046
# +++ /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py:after	2022-04-22 21:51:46.624729
# @@ -1,7 +1,8 @@
#  import unittest
#  from unittest.mock import call, patch
#
# -from patterns.behavioral.publish_subscribe import Provider, Publisher, Subscriber
# +from patterns.behavioral.publish_subscribe import (Provider, Publisher,
# +                                                   Subscriber)
#
#
#  class TestProvider(unittest.TestCase):
# ERROR: /workspaces/python-patterns/tests/behavioral/test_strategy.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/behavioral/test_strategy.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/behavioral/test_strategy.py:after	2022-04-22 21:51:46.671686
# @@ -1,6 +1,7 @@
#  import pytest
#
# -from patterns.behavioral.strategy import Order, ten_percent_discount, on_sale_discount
# +from patterns.behavioral.strategy import (Order, on_sale_discount,
# +                                          ten_percent_discount)
#
#
#  @pytest.fixture
# ERROR: /workspaces/python-patterns/tests/creational/test_builder.py Imports are incorrectly sorted and/or formatted.
# --- /workspaces/python-patterns/tests/creational/test_builder.py:before	2022-04-22 21:28:57.130669
# +++ /workspaces/python-patterns/tests/creational/test_builder.py:after	2022-04-22 21:51:46.793556
# @@ -1,6 +1,7 @@
#  import unittest
#
# -from patterns.creational.builder import ComplexHouse, Flat, House, construct_building
# +from patterns.creational.builder import (ComplexHouse, Flat, House,
# +                                         construct_building)
#
#
#  class TestSimple(unittest.TestCase):

# %%
# isort setup ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort --check-only --df setup.py

# %% [markdown]
# ---
#
# ### `twine`

# %%
# twine check dist/* ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && twine check .tox/dist/*
# tox.ini needs to be run first
# Out:
# /bin/bash: line 1: twine: command not found

# %%
#! check-manifest  # needs `apt-get install python3-venv`

# %% [markdown]
# ---
#
# ## Fixers: `isort`, `black`, and `mypy`
#
# __[testenv:fixers]__
#
# Fix - Readability and style enforcement.
#
# Minimal Requirements:
#
# - fix all warnings
# - gradual typing

# %%
# versions used for testing ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! python --version
! black --version
! isort --version
! mypy --version
! pip freeze | grep mypy-extensions
! pip freeze | grep types-PyYAML
# Out:
# Python 3.10.4
# black, 22.3.0 (compiled: yes)
#
#                  _                 _
#                 (_) ___  ___  _ __| |_
#                 | |/ _/ / _ \/ '__  _/
#                 | |\__ \/\_\/| |  | |_
#                 |_|\___/\___/\_/   \_/
#
#       isort your imports, so you don't have to.
#
#                     VERSION 5.7.0
#
# mypy 0.942
# mypy-extensions==0.4.3
# types-PyYAML==6.0.7

# %% [markdown]
# ---
#
# ### `isort`

# %%
# isort all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && isort patterns/ tests/ setup.py
# Out:
# Fixing /workspaces/python-patterns/patterns/behavioral/memento.py
# Fixing /workspaces/python-patterns/tests/test_hsm.py
# Fixing /workspaces/python-patterns/tests/behavioral/test_publish_subscribe.py
# Fixing /workspaces/python-patterns/tests/behavioral/test_strategy.py
# Fixing /workspaces/python-patterns/tests/creational/test_builder.py

# %% [markdown]
# ---
#
# ### `black`

# %%
# black all ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd ..&& black --version && black patterns/ tests/ setup.py
# Out:
# black, 22.3.0 (compiled: yes)
# reformatted setup.py
# reformatted tests/behavioral/test_strategy.py
# reformatted tests/creational/test_builder.py
# reformatted tests/behavioral/test_publish_subscribe.py
# reformatted tests/test_hsm.py
#
# All done! ✨ 🍰 ✨
# 5 files reformatted, 57 files left unchanged.

# %% [markdown]
# ---
#
# ## `mypy`
#
# Run `mypy` on the `/src` and `tests`
#
# - gradual typing

# %%
# mypy patterns ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && mypy patterns
# Out:
# Success: no issues found in 46 source files

# %%
# mypy tests ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && mypy tests
# Out:
# Success: no issues found in 15 source files

# %% [markdown]
# Full check on type hinting.

# %%
# mypy --config-file ../mypy_full_check.ini -p patterns ~~~~~~~~~~~~~~~~~
! cd .. && mypy --config-file mypy_full_check.ini -p patterns
# Out:
# patterns/other/hsm/hsm.py:25: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/other/hsm/hsm.py:25: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:26: error: Call to untyped function "Active" in typed
# context  [no-untyped-call]
#             self._active_state = Active(self)  # Unit.Inservice.Active()
#                                  ^
# patterns/other/hsm/hsm.py:27: error: Call to untyped function "Standby" in
# typed context  [no-untyped-call]
#             self._standby_state = Standby(self)  # Unit.Inservice.Standby(...
#                                   ^
# patterns/other/hsm/hsm.py:28: error: Call to untyped function "Suspect" in
# typed context  [no-untyped-call]
#             self._suspect_state = Suspect(self)  # Unit.OutOfService.Suspe...
#                                   ^
# patterns/other/hsm/hsm.py:29: error: Call to untyped function "Failed" in typed
# context  [no-untyped-call]
#             self._failed_state = Failed(self)  # Unit.OutOfService.Failed(...
#                                  ^
# patterns/other/hsm/hsm.py:45: error: Function is missing a type annotation
# [no-untyped-def]
#         def _next_state(self, state):
#         ^
# patterns/other/hsm/hsm.py:47: error: Incompatible types in assignment
# (expression has type "Unit", variable has type "Standby")  [assignment]
#                 self._current_state = self.states[state]
#                                       ^
# patterns/other/hsm/hsm.py:51: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _send_diagnostics_request(self):
#         ^
# patterns/other/hsm/hsm.py:54: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _raise_alarm(self):
#         ^
# patterns/other/hsm/hsm.py:57: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _clear_alarm(self):
#         ^
# patterns/other/hsm/hsm.py:60: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _perform_switchover(self):
#         ^
# patterns/other/hsm/hsm.py:63: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _send_switchover_response(self):
#         ^
# patterns/other/hsm/hsm.py:66: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _send_operator_inservice_response(self):
#         ^
# patterns/other/hsm/hsm.py:69: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _send_diagnostics_failure_report(self):
#         ^
# patterns/other/hsm/hsm.py:72: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _send_diagnostics_pass_report(self):
#         ^
# patterns/other/hsm/hsm.py:75: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _abort_diagnostics(self):
#         ^
# patterns/other/hsm/hsm.py:78: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def _check_mate_status(self):
#         ^
# patterns/other/hsm/hsm.py:81: error: Function is missing a type annotation
# [no-untyped-def]
#         def on_message(self, message_type):  # message ignored
#         ^
# patterns/other/hsm/hsm.py:83: error: Call to untyped function (unknown) in
# typed context  [no-untyped-call]
#                 self.message_types[message_type]()
#                 ^
# patterns/other/hsm/hsm.py:89: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/other/hsm/hsm.py:92: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_switchover(self):
#         ^
# patterns/other/hsm/hsm.py:92: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:95: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_fault_trigger(self):
#         ^
# patterns/other/hsm/hsm.py:95: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:98: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_diagnostics_failed(self):
#         ^
# patterns/other/hsm/hsm.py:98: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:101: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_diagnostics_passed(self):
#         ^
# patterns/other/hsm/hsm.py:101: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:104: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_operator_inservice(self):
#         ^
# patterns/other/hsm/hsm.py:104: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:109: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/other/hsm/hsm.py:112: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_fault_trigger(self):
#         ^
# patterns/other/hsm/hsm.py:112: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:117: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_switchover(self):
#         ^
# patterns/other/hsm/hsm.py:117: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:124: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/other/hsm/hsm.py:127: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_fault_trigger(self):
#         ^
# patterns/other/hsm/hsm.py:127: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:128: error: "perform_switchover" undefined in
# superclass  [misc]
#             super().perform_switchover()
#             ^
# patterns/other/hsm/hsm.py:129: error: Call to untyped function
# "on_fault_trigger" in typed context  [no-untyped-call]
#             super().on_fault_trigger()
#             ^
# patterns/other/hsm/hsm.py:131: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_switchover(self):
#         ^
# patterns/other/hsm/hsm.py:131: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:137: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/other/hsm/hsm.py:140: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_switchover(self):
#         ^
# patterns/other/hsm/hsm.py:140: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:141: error: Call to untyped function "on_switchover"
# in typed context  [no-untyped-call]
#             super().on_switchover()  # message ignored
#             ^
# patterns/other/hsm/hsm.py:146: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/other/hsm/hsm.py:149: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_operator_inservice(self):
#         ^
# patterns/other/hsm/hsm.py:149: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:156: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/other/hsm/hsm.py:159: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_diagnostics_failed(self):
#         ^
# patterns/other/hsm/hsm.py:159: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:160: error: "send_diagnostics_failure_report"
# undefined in superclass  [misc]
#             super().send_diagnostics_failure_report()
#             ^
# patterns/other/hsm/hsm.py:161: error: "next_state" undefined in superclass
# [misc]
#             super().next_state("failed")
#             ^
# patterns/other/hsm/hsm.py:163: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_diagnostics_passed(self):
#         ^
# patterns/other/hsm/hsm.py:163: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:164: error: "send_diagnostics_pass_report" undefined
# in superclass  [misc]
#             super().send_diagnostics_pass_report()
#             ^
# patterns/other/hsm/hsm.py:165: error: "clear_alarm" undefined in superclass
# [misc]
#             super().clear_alarm()  # loss of redundancy alarm
#             ^
# patterns/other/hsm/hsm.py:166: error: "next_state" undefined in superclass
# [misc]
#             super().next_state("standby")
#             ^
# patterns/other/hsm/hsm.py:168: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def on_operator_inservice(self):
#         ^
# patterns/other/hsm/hsm.py:168: note: Use "-> None" if function does not return a value
# patterns/other/hsm/hsm.py:169: error: "abort_diagnostics" undefined in
# superclass  [misc]
#             super().abort_diagnostics()
#             ^
# patterns/other/hsm/hsm.py:170: error: Call to untyped function
# "on_operator_inservice" in typed context  [no-untyped-call]
#             super().on_operator_inservice()  # message ignored
#             ^
# patterns/other/hsm/hsm.py:176: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, HierachicalStateMachine):
#         ^
# patterns/structural/flyweight_with_metaclass.py:5: error: Function is missing a
# type annotation  [no-untyped-def]
#         def __new__(mcs, name, parents, dct):
#         ^
# patterns/structural/flyweight_with_metaclass.py:19: error: Function is missing
# a type annotation  [no-untyped-def]
#         def _serialize_params(cls, *args, **kwargs):
#         ^
# patterns/structural/flyweight_with_metaclass.py:29: error: Function is missing
# a type annotation  [no-untyped-def]
#         def __call__(cls, *args, **kwargs):
#         ^
# patterns/structural/flyweight_with_metaclass.py:30: error: Call to untyped
# function "_serialize_params" of "FlyweightMeta" in typed context
# [no-untyped-call]
#             key = FlyweightMeta._serialize_params(cls, *args, **kwargs)
#                   ^
# patterns/structural/flyweight_with_metaclass.py:41: error: Function is missing
# a type annotation  [no-untyped-def]
#         def __init__(self, *args, **kwargs):
#         ^
# patterns/structural/flyweight_with_metaclass.py:48: error: Call to untyped
# function "Card2" in typed context  [no-untyped-call]
#         cm1 = Card2("10", "h", a=1)
#               ^
# patterns/structural/flyweight_with_metaclass.py:49: error: Call to untyped
# function "Card2" in typed context  [no-untyped-call]
#         cm2 = Card2("10", "h", a=1)
#               ^
# patterns/structural/flyweight_with_metaclass.py:50: error: Call to untyped
# function "Card2" in typed context  [no-untyped-call]
#         cm3 = Card2("10", "h", a=2)
#               ^
# patterns/structural/proxy.py:66: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/proxy.py:66: note: Use "-> None" if function does not return a value
# patterns/structural/mvc.py:11: error: Function is missing a type annotation
# [no-untyped-def]
#         def __iter__(self):
#         ^
# patterns/structural/mvc.py:15: error: Function is missing a type annotation
# [no-untyped-def]
#         def get(self, item):
#         ^
# patterns/structural/mvc.py:22: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def item_type(self):
#         ^
# patterns/structural/mvc.py:22: note: Use "-> None" if function does not return a value
# patterns/structural/mvc.py:31: error: Function is missing a type annotation
# [no-untyped-def]
#             def __str__(self):
#             ^
# patterns/structural/mvc.py:42: error: Function is missing a type annotation
# [no-untyped-def]
#         def __iter__(self):
#         ^
# patterns/structural/mvc.py:45: error: Function is missing a type annotation
# [no-untyped-def]
#         def get(self, product):
#         ^
# patterns/structural/mvc.py:54: error: Function is missing a type annotation
# [no-untyped-def]
#         def show_item_list(self, item_type, item_list):
#         ^
# patterns/structural/mvc.py:58: error: Function is missing a type annotation
# [no-untyped-def]
#         def show_item_information(self, item_type, item_name, item_info):
#         ^
# patterns/structural/mvc.py:64: error: Function is missing a type annotation
# [no-untyped-def]
#         def item_not_found(self, item_type, item_name):
#         ^
# patterns/structural/mvc.py:69: error: Function is missing a type annotation
# [no-untyped-def]
#         def show_item_list(self, item_type, item_list):
#         ^
# patterns/structural/mvc.py:76: error: Function is missing a type annotation
# [no-untyped-def]
#         def capitalizer(string):
#         ^
# patterns/structural/mvc.py:79: error: Function is missing a type annotation
# [no-untyped-def]
#         def show_item_information(self, item_type, item_name, item_info):
#         ^
# patterns/structural/mvc.py:83: error: Call to untyped function "capitalizer" of
# "ConsoleView" in typed context  [no-untyped-call]
#                 printout += ", " + self.capitalizer(str(key)) + ": " + str...
#                                    ^
# patterns/structural/mvc.py:87: error: Function is missing a type annotation
# [no-untyped-def]
#         def item_not_found(self, item_type, item_name):
#         ^
# patterns/structural/mvc.py:92: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, model, view):
#         ^
# patterns/structural/mvc.py:96: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def show_items(self):
#         ^
# patterns/structural/mvc.py:96: note: Use "-> None" if function does not return a value
# patterns/structural/mvc.py:101: error: Function is missing a type annotation
# [no-untyped-def]
#         def show_item_information(self, item_name):
#         ^
# patterns/structural/mvc.py:116: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/mvc.py:116: note: Use "-> None" if function does not return a value
# patterns/structural/front_controller.py:10: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def show_index_page(self):
#         ^
# patterns/structural/front_controller.py:10: note: Use "-> None" if function does not return a value
# patterns/structural/front_controller.py:15: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def show_index_page(self):
#         ^
# patterns/structural/front_controller.py:15: note: Use "-> None" if function does not return a value
# patterns/structural/front_controller.py:20: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/structural/front_controller.py:20: note: Use "-> None" if function does not return a value
# patterns/structural/front_controller.py:24: error: Function is missing a type
# annotation  [no-untyped-def]
#         def dispatch(self, request):
#         ^
# patterns/structural/front_controller.py:32: error: Call to untyped function
# "show_index_page" in typed context  [no-untyped-call]
#                 self.mobile_view.show_index_page()
#                 ^
# patterns/structural/front_controller.py:34: error: Call to untyped function
# "show_index_page" in typed context  [no-untyped-call]
#                 self.tablet_view.show_index_page()
#                 ^
# patterns/structural/front_controller.py:42: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/structural/front_controller.py:42: note: Use "-> None" if function does not return a value
# patterns/structural/front_controller.py:43: error: Call to untyped function
# "Dispatcher" in typed context  [no-untyped-call]
#             self.dispatcher = Dispatcher()
#                               ^
# patterns/structural/front_controller.py:45: error: Function is missing a type
# annotation  [no-untyped-def]
#         def dispatch_request(self, request):
#         ^
# patterns/structural/front_controller.py:50: error: Call to untyped function
# "dispatch" in typed context  [no-untyped-call]
#                 self.dispatcher.dispatch(request)
#                 ^
# patterns/structural/front_controller.py:61: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, request):
#         ^
# patterns/structural/front_controller.py:70: error: Function is missing a return
# type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/front_controller.py:70: note: Use "-> None" if function does not return a value
# patterns/structural/flyweight.py:37: error: Missing type parameters for generic
# type "WeakValueDictionary"  [type-arg]
#         _pool: weakref.WeakValueDictionary = weakref.WeakValueDictionary()
#                ^
# patterns/structural/flyweight.py:39: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __new__(cls, value, suit):
#         ^
# patterns/structural/flyweight.py:47: error: "Card" has no attribute "value"
# [attr-defined]
#                 obj.value, obj.suit = value, suit
#                 ^
# patterns/structural/flyweight.py:47: error: "Card" has no attribute "suit"
# [attr-defined]
#                 obj.value, obj.suit = value, suit
#                            ^
# patterns/structural/flyweight.py:55: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __repr__(self):
#         ^
# patterns/structural/flyweight.py:56: error: "Card" has no attribute "value"
# [attr-defined]
#             return f"<Card: {self.value}{self.suit}>"
#                    ^
# patterns/structural/flyweight.py:56: error: "Card" has no attribute "suit"
# [attr-defined]
#             return f"<Card: {self.value}{self.suit}>"
#                    ^
# patterns/structural/flyweight.py:59: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/flyweight.py:59: note: Use "-> None" if function does not return a value
# patterns/structural/facade.py:38: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def freeze(self):
#         ^
# patterns/structural/facade.py:38: note: Use "-> None" if function does not return a value
# patterns/structural/facade.py:41: error: Function is missing a type annotation
# [no-untyped-def]
#         def jump(self, position):
#         ^
# patterns/structural/facade.py:44: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def execute(self):
#         ^
# patterns/structural/facade.py:44: note: Use "-> None" if function does not return a value
# patterns/structural/facade.py:53: error: Function is missing a type annotation
# [no-untyped-def]
#         def load(self, position, data):
#         ^
# patterns/structural/facade.py:62: error: Function is missing a type annotation
# [no-untyped-def]
#         def read(self, lba, size):
#         ^
# patterns/structural/facade.py:71: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/structural/facade.py:71: note: Use "-> None" if function does not return a value
# patterns/structural/facade.py:76: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def start(self):
#         ^
# patterns/structural/facade.py:76: note: Use "-> None" if function does not return a value
# patterns/structural/facade.py:77: error: Call to untyped function "freeze" in
# typed context  [no-untyped-call]
#             self.cpu.freeze()
#             ^
# patterns/structural/facade.py:78: error: Call to untyped function "load" in
# typed context  [no-untyped-call]
#             self.memory.load("0x00", self.ssd.read("100", "1024"))
#             ^
# patterns/structural/facade.py:78: error: Call to untyped function "read" in
# typed context  [no-untyped-call]
#             self.memory.load("0x00", self.ssd.read("100", "1024"))
#                                      ^
# patterns/structural/facade.py:79: error: Call to untyped function "jump" in
# typed context  [no-untyped-call]
#             self.cpu.jump("0x00")
#             ^
# patterns/structural/facade.py:80: error: Call to untyped function "execute" in
# typed context  [no-untyped-call]
#             self.cpu.execute()
#             ^
# patterns/structural/facade.py:83: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/facade.py:83: note: Use "-> None" if function does not return a value
# patterns/structural/decorator.py:31: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, text):
#         ^
# patterns/structural/decorator.py:34: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def render(self):
#         ^
# patterns/structural/decorator.py:41: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, wrapped):
#         ^
# patterns/structural/decorator.py:44: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def render(self):
#         ^
# patterns/structural/decorator.py:51: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, wrapped):
#         ^
# patterns/structural/decorator.py:54: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def render(self):
#         ^
# patterns/structural/decorator.py:58: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/decorator.py:58: note: Use "-> None" if function does not return a value
# patterns/structural/composite.py:62: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/composite.py:62: note: Use "-> None" if function does not return a value
# patterns/structural/bridge.py:12: error: Function is missing a type annotation
# [no-untyped-def]
#         def draw_circle(self, x, y, radius):
#         ^
# patterns/structural/bridge.py:18: error: Function is missing a type annotation
# [no-untyped-def]
#         def draw_circle(self, x, y, radius):
#         ^
# patterns/structural/bridge.py:24: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, x, y, radius, drawing_api):
#         ^
# patterns/structural/bridge.py:31: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def draw(self):
#         ^
# patterns/structural/bridge.py:31: note: Use "-> None" if function does not return a value
# patterns/structural/bridge.py:35: error: Function is missing a type annotation
# [no-untyped-def]
#         def scale(self, pct):
#         ^
# patterns/structural/bridge.py:39: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/bridge.py:39: note: Use "-> None" if function does not return a value
# patterns/structural/adapter.py:77: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#         def __init__(self, obj: T, **adapted_methods: Callable):
#                                                       ^
# patterns/structural/adapter.py:82: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __getattr__(self, attr):
#         ^
# patterns/structural/adapter.py:86: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def original_dict(self):
#         ^
# patterns/structural/adapter.py:91: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/adapter.py:91: note: Use "-> None" if function does not return a value
# patterns/structural/3-tier.py:18: error: Function is missing a type annotation
# [no-untyped-def]
#         def __get__(self, obj, klas):
#         ^
# patterns/structural/3-tier.py:63: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/structural/3-tier.py:63: note: Use "-> None" if function does not return a value
# patterns/other/graph_search.py:9: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, graph):
#         ^
# patterns/other/graph_search.py:12: error: Function is missing a type annotation
#  [no-untyped-def]
#         def find_path_dfs(self, start, end, path=None):
#         ^
# patterns/other/graph_search.py:20: error: Call to untyped function
# "find_path_dfs" in typed context  [no-untyped-call]
#                     newpath = self.find_path_dfs(node, end, path[:])
#                               ^
# patterns/other/graph_search.py:24: error: Function is missing a type annotation
#  [no-untyped-def]
#         def find_all_paths_dfs(self, start, end, path=None):
#         ^
# patterns/other/graph_search.py:32: error: Call to untyped function
# "find_all_paths_dfs" in typed context  [no-untyped-call]
#                     newpaths = self.find_all_paths_dfs(node, end, path[:])
#                                ^
# patterns/other/graph_search.py:36: error: Function is missing a type annotation
#  [no-untyped-def]
#         def find_shortest_path_dfs(self, start, end, path=None):
#         ^
# patterns/other/graph_search.py:45: error: Call to untyped function
# "find_shortest_path_dfs" in typed context  [no-untyped-call]
#                     newpath = self.find_shortest_path_dfs(node, end, path[...
#                               ^
# patterns/other/graph_search.py:51: error: Function is missing a type annotation
#  [no-untyped-def]
#         def find_shortest_path_bfs(self, start, end):
#         ^
# patterns/other/graph_search.py:81: error: Need type annotation for "path"
# (hint: "path: List[<type>] = ...")  [var-annotated]
#                             path = []
#                             ^
# patterns/other/graph_search.py:90: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/other/graph_search.py:90: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:17: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/other/blackboard.py:17: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:26: error: Function is missing a type annotation
# [no-untyped-def]
#         def add_expert(self, expert):
#         ^
# patterns/other/blackboard.py:31: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, blackboard):
#         ^
# patterns/other/blackboard.py:34: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def run_loop(self):
#         ^
# patterns/other/blackboard.py:47: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, blackboard):
#         ^
# patterns/other/blackboard.py:52: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def is_eager_to_contribute(self):
#         ^
# patterns/other/blackboard.py:52: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:56: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def contribute(self):
#         ^
# patterns/other/blackboard.py:56: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:62: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def is_eager_to_contribute(self):
#         ^
# patterns/other/blackboard.py:65: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def contribute(self):
#         ^
# patterns/other/blackboard.py:65: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:74: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def is_eager_to_contribute(self):
#         ^
# patterns/other/blackboard.py:77: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def contribute(self):
#         ^
# patterns/other/blackboard.py:77: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:86: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def is_eager_to_contribute(self):
#         ^
# patterns/other/blackboard.py:89: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def contribute(self):
#         ^
# patterns/other/blackboard.py:89: note: Use "-> None" if function does not return a value
# patterns/other/blackboard.py:96: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/other/blackboard.py:96: note: Use "-> None" if function does not return a value
# patterns/fundamental/delegation_pattern.py:34: error: Missing type parameters
# for generic type "Callable"  [type-arg]
#         def __getattr__(self, name: str) -> Any | Callable:
#                                                   ^
# patterns/fundamental/delegation_pattern.py:40: error: Function is missing a
# type annotation  [no-untyped-def]
#             def wrapper(*args, **kwargs):
#             ^
# patterns/fundamental/delegation_pattern.py:47: error: Function is missing a
# return type annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/fundamental/delegation_pattern.py:47: note: Use "-> None" if function does not return a value
# patterns/dependency_injection.py:31: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#         def __init__(self, time_provider: Callable) -> None:
#                                           ^
# patterns/dependency_injection.py:46: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#     ...t_current_time_as_html_fragment(self, time_provider: Callable) -> str:
#                                                             ^
# patterns/dependency_injection.py:57: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/dependency_injection.py:57: note: Use "-> None" if function does not return a value
# patterns/dependency_injection.py:60: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def set_time_provider(self, time_provider: Callable):
#         ^
# patterns/dependency_injection.py:60: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#         def set_time_provider(self, time_provider: Callable):
#                                                    ^
# patterns/dependency_injection.py:63: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def get_current_time_as_html_fragment(self):
#         ^
# patterns/dependency_injection.py:86: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/dependency_injection.py:86: note: Use "-> None" if function does not return a value
# patterns/creational/prototype.py:43: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/creational/prototype.py:43: note: Use "-> None" if function does not return a value
# patterns/creational/pool.py:33: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, queue, auto_get=False):
#         ^
# patterns/creational/pool.py:37: error: Function is missing a type annotation
# [no-untyped-def]
#         def __enter__(self):
#         ^
# patterns/creational/pool.py:42: error: Function is missing a type annotation
# [no-untyped-def]
#         def __exit__(self, Type, value, traceback):
#         ^
# patterns/creational/pool.py:47: error: Function is missing a type annotation
# [no-untyped-def]
#         def __del__(self):
#         ^
# patterns/creational/pool.py:53: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/creational/pool.py:53: note: Use "-> None" if function does not return a value
# patterns/creational/lazy_evaluation.py:26: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, function):
#         ^
# patterns/creational/lazy_evaluation.py:30: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __get__(self, obj, type_):
#         ^
# patterns/creational/lazy_evaluation.py:38: error: Function is missing a type
# annotation  [no-untyped-def]
#     def lazy_property2(fn):
#     ^
# patterns/creational/lazy_evaluation.py:47: error: "property" used with a
# non-method  [misc]
#         @property
#          ^
# patterns/creational/lazy_evaluation.py:48: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def _lazy_property(self):
#         ^
# patterns/creational/lazy_evaluation.py:57: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, name, occupation):
#         ^
# patterns/creational/lazy_evaluation.py:63: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def relatives(self):
#         ^
# patterns/creational/lazy_evaluation.py:69: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def parents(self):
#         ^
# patterns/creational/lazy_evaluation.py:74: error: Function is missing a return
# type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/creational/lazy_evaluation.py:74: note: Use "-> None" if function does not return a value
# patterns/creational/factory.py:58: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/creational/factory.py:58: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:37: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/creational/builder.py:37: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:38: error: Call to untyped function
# "build_floor" in typed context  [no-untyped-call]
#             self.build_floor()
#             ^
# patterns/creational/builder.py:39: error: Call to untyped function "build_size"
# in typed context  [no-untyped-call]
#             self.build_size()
#             ^
# patterns/creational/builder.py:41: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_floor(self):
#         ^
# patterns/creational/builder.py:41: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:44: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_size(self):
#         ^
# patterns/creational/builder.py:44: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:47: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __repr__(self):
#         ^
# patterns/creational/builder.py:48: error: "Building" has no attribute "floor"
# [attr-defined]
#             return "Floor: {0.floor} | Size: {0.size}".format(self)
#                    ^
# patterns/creational/builder.py:48: error: "Building" has no attribute "size"
# [attr-defined]
#             return "Floor: {0.floor} | Size: {0.size}".format(self)
#                    ^
# patterns/creational/builder.py:53: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_floor(self):
#         ^
# patterns/creational/builder.py:53: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:56: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_size(self):
#         ^
# patterns/creational/builder.py:56: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:61: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_floor(self):
#         ^
# patterns/creational/builder.py:61: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:64: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_size(self):
#         ^
# patterns/creational/builder.py:64: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:75: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __repr__(self):
#         ^
# patterns/creational/builder.py:76: error: "ComplexBuilding" has no attribute
# "floor"  [attr-defined]
#             return "Floor: {0.floor} | Size: {0.size}".format(self)
#                    ^
# patterns/creational/builder.py:76: error: "ComplexBuilding" has no attribute
# "size"  [attr-defined]
#             return "Floor: {0.floor} | Size: {0.size}".format(self)
#                    ^
# patterns/creational/builder.py:80: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_floor(self):
#         ^
# patterns/creational/builder.py:80: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:83: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def build_size(self):
#         ^
# patterns/creational/builder.py:83: note: Use "-> None" if function does not return a value
# patterns/creational/builder.py:87: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def construct_building(cls):
#     ^
# patterns/creational/builder.py:94: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/creational/builder.py:94: note: Use "-> None" if function does not return a value
# patterns/creational/borg.py:41: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/creational/borg.py:41: note: Use "-> None" if function does not return a value
# patterns/creational/borg.py:46: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, state=None):
#         ^
# patterns/creational/borg.py:47: error: Call to untyped function "__init__" in
# typed context  [no-untyped-call]
#             super().__init__()
#             ^
# patterns/creational/borg.py:55: error: Function is missing a type annotation
# [no-untyped-def]
#         def __str__(self):
#         ^
# patterns/creational/borg.py:59: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/creational/borg.py:59: note: Use "-> None" if function does not return a value
# patterns/behavioral/visitor.py:36: error: Function is missing a type annotation
#  [no-untyped-def]
#         def visit(self, node, *args, **kwargs):
#         ^
# patterns/behavioral/visitor.py:48: error: Function is missing a type annotation
#  [no-untyped-def]
#         def generic_visit(self, node, *args, **kwargs):
#         ^
# patterns/behavioral/visitor.py:51: error: Function is missing a type annotation
#  [no-untyped-def]
#         def visit_B(self, node, *args, **kwargs):
#         ^
# patterns/behavioral/visitor.py:55: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/visitor.py:55: note: Use "-> None" if function does not return a value
# patterns/behavioral/template.py:13: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def get_text():
#     ^
# patterns/behavioral/template.py:17: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def get_pdf():
#     ^
# patterns/behavioral/template.py:21: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def get_csv():
#     ^
# patterns/behavioral/template.py:25: error: Function is missing a type
# annotation  [no-untyped-def]
#     def convert_to_text(data):
#     ^
# patterns/behavioral/template.py:30: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def saver():
#     ^
# patterns/behavioral/template.py:30: note: Use "-> None" if function does not return a value
# patterns/behavioral/template.py:34: error: Function is missing a type
# annotation  [no-untyped-def]
#     def template_function(getter, converter=False, to_save=False):
#     ^
# patterns/behavioral/template.py:44: error: Call to untyped function "saver" in
# typed context  [no-untyped-call]
#             saver()
#             ^
# patterns/behavioral/template.py:49: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/template.py:49: note: Use "-> None" if function does not return a value
# patterns/behavioral/strategy.py:18: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#         def validate(obj: Order, value: Callable) -> bool:
#                                         ^
# patterns/behavioral/strategy.py:30: error: Function is missing a type
# annotation for one or more arguments  [no-untyped-def]
#         def __set_name__(self, owner, name: str) -> None:
#         ^
# patterns/behavioral/strategy.py:33: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#         def __set__(self, obj: Order, value: Callable = None) -> None:
#                                              ^
# patterns/behavioral/strategy.py:33: error: Incompatible default for argument
# "value" (default has type "None", argument has type "Callable[..., Any]")
# [assignment]
#         def __set__(self, obj: Order, value: Callable = None) -> None:
#                                                         ^
# patterns/behavioral/strategy.py:39: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __get__(self, obj: object, objtype: type = None):
#         ^
# patterns/behavioral/strategy.py:39: error: Incompatible default for argument
# "objtype" (default has type "None", argument has type "type")  [assignment]
#         def __get__(self, obj: object, objtype: type = None):
#                                                        ^
# patterns/behavioral/strategy.py:46: error: Missing type parameters for generic
# type "Callable"  [type-arg]
#     ... __init__(self, price: float, discount_strategy: Callable = None) -> N...
#                                                         ^
# patterns/behavioral/strategy.py:46: error: Incompatible default for argument
# "discount_strategy" (default has type "None", argument has type
# "Callable[..., Any]")  [assignment]
#     ...nit__(self, price: float, discount_strategy: Callable = None) -> None:
#                                                                ^
# patterns/behavioral/strategy.py:70: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/strategy.py:70: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:16: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def scan(self):
#         ^
# patterns/behavioral/state.py:16: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:18: error: Cannot determine type of "pos"
# [has-type]
#             self.pos += 1
#             ^
# patterns/behavioral/state.py:19: error: Cannot determine type of "pos"
# [has-type]
#             if self.pos == len(self.stations):
#                ^
# patterns/behavioral/state.py:19: error: "State" has no attribute "stations"
# [attr-defined]
#             if self.pos == len(self.stations):
#                                ^
# patterns/behavioral/state.py:21: error: "State" has no attribute "name"
# [attr-defined]
#             print(f"Scanning... Station is {self.stations[self.pos]} {self...
#                   ^
# patterns/behavioral/state.py:21: error: "State" has no attribute "stations"
# [attr-defined]
#             print(f"Scanning... Station is {self.stations[self.pos]} {self...
#                                             ^
# patterns/behavioral/state.py:25: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, radio):
#         ^
# patterns/behavioral/state.py:31: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def toggle_amfm(self):
#         ^
# patterns/behavioral/state.py:31: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:37: error: Function is missing a type annotation
# [no-untyped-def]
#         def __init__(self, radio):
#         ^
# patterns/behavioral/state.py:43: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def toggle_amfm(self):
#         ^
# patterns/behavioral/state.py:43: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:52: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/behavioral/state.py:52: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:54: error: Call to untyped function "AmState" in
# typed context  [no-untyped-call]
#             self.amstate = AmState(self)
#                            ^
# patterns/behavioral/state.py:55: error: Call to untyped function "FmState" in
# typed context  [no-untyped-call]
#             self.fmstate = FmState(self)
#                            ^
# patterns/behavioral/state.py:58: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def toggle_amfm(self):
#         ^
# patterns/behavioral/state.py:58: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:59: error: Call to untyped function "toggle_amfm"
# in typed context  [no-untyped-call]
#             self.state.toggle_amfm()
#             ^
# patterns/behavioral/state.py:61: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def scan(self):
#         ^
# patterns/behavioral/state.py:61: note: Use "-> None" if function does not return a value
# patterns/behavioral/state.py:62: error: Call to untyped function "scan" in
# typed context  [no-untyped-call]
#             self.state.scan()
#             ^
# patterns/behavioral/state.py:65: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/state.py:65: note: Use "-> None" if function does not return a value
# patterns/behavioral/specification.py:12: error: Function is missing a type
# annotation  [no-untyped-def]
#         def and_specification(self, candidate):
#         ^
# patterns/behavioral/specification.py:15: error: Function is missing a type
# annotation  [no-untyped-def]
#         def or_specification(self, candidate):
#         ^
# patterns/behavioral/specification.py:18: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def not_specification(self):
#         ^
# patterns/behavioral/specification.py:18: note: Use "-> None" if function does not return a value
# patterns/behavioral/specification.py:22: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:28: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:31: error: Function is missing a type
# annotation  [no-untyped-def]
#         def and_specification(self, candidate):
#         ^
# patterns/behavioral/specification.py:32: error: Call to untyped function
# "AndSpecification" in typed context  [no-untyped-call]
#             return AndSpecification(self, candidate)
#                    ^
# patterns/behavioral/specification.py:34: error: Function is missing a type
# annotation  [no-untyped-def]
#         def or_specification(self, candidate):
#         ^
# patterns/behavioral/specification.py:35: error: Call to untyped function
# "OrSpecification" in typed context  [no-untyped-call]
#             return OrSpecification(self, candidate)
#                    ^
# patterns/behavioral/specification.py:37: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def not_specification(self):
#         ^
# patterns/behavioral/specification.py:38: error: Call to untyped function
# "NotSpecification" in typed context  [no-untyped-call]
#             return NotSpecification(self)
#                    ^
# patterns/behavioral/specification.py:42: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, one, other):
#         ^
# patterns/behavioral/specification.py:46: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:48: error: Call to untyped function
# "is_satisfied_by" of "Specification" in typed context  [no-untyped-call]
#                 self._one.is_satisfied_by(candidate)
#                 ^
# patterns/behavioral/specification.py:49: error: Call to untyped function
# "is_satisfied_by" of "Specification" in typed context  [no-untyped-call]
#                 and self._other.is_satisfied_by(candidate)
#                     ^
# patterns/behavioral/specification.py:54: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, one, other):
#         ^
# patterns/behavioral/specification.py:58: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:60: error: Call to untyped function
# "is_satisfied_by" of "Specification" in typed context  [no-untyped-call]
#                 self._one.is_satisfied_by(candidate)
#                 ^
# patterns/behavioral/specification.py:61: error: Call to untyped function
# "is_satisfied_by" of "Specification" in typed context  [no-untyped-call]
#                 or self._other.is_satisfied_by(candidate)
#                    ^
# patterns/behavioral/specification.py:66: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, wrapped):
#         ^
# patterns/behavioral/specification.py:69: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:70: error: Call to untyped function
# "is_satisfied_by" of "Specification" in typed context  [no-untyped-call]
#             return bool(not self._wrapped.is_satisfied_by(candidate))
#                             ^
# patterns/behavioral/specification.py:74: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, super_user=False):
#         ^
# patterns/behavioral/specification.py:79: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:84: error: Function is missing a type
# annotation  [no-untyped-def]
#         def is_satisfied_by(self, candidate):
#         ^
# patterns/behavioral/specification.py:88: error: Function is missing a return
# type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/specification.py:88: note: Use "-> None" if function does not return a value
# patterns/behavioral/registry.py:8: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __new__(cls, name, bases, attrs):
#         ^
# patterns/behavioral/registry.py:18: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def get_registry(cls):
#         ^
# patterns/behavioral/registry.py:30: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/registry.py:30: note: Use "-> None" if function does not return a value
# patterns/behavioral/publish_subscribe.py:9: error: Function is missing a return
# type annotation  [no-untyped-def]
#         def __init__(self):
#         ^
# patterns/behavioral/publish_subscribe.py:9: note: Use "-> None" if function does not return a value
# patterns/behavioral/publish_subscribe.py:13: error: Function is missing a type
# annotation  [no-untyped-def]
#         def notify(self, msg):
#         ^
# patterns/behavioral/publish_subscribe.py:16: error: Function is missing a type
# annotation  [no-untyped-def]
#         def subscribe(self, msg, subscriber):
#         ^
# patterns/behavioral/publish_subscribe.py:19: error: Function is missing a type
# annotation  [no-untyped-def]
#         def unsubscribe(self, msg, subscriber):
#         ^
# patterns/behavioral/publish_subscribe.py:22: error: Function is missing a
# return type annotation  [no-untyped-def]
#         def update(self):
#         ^
# patterns/behavioral/publish_subscribe.py:22: note: Use "-> None" if function does not return a value
# patterns/behavioral/publish_subscribe.py:30: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, msg_center):
#         ^
# patterns/behavioral/publish_subscribe.py:33: error: Function is missing a type
# annotation  [no-untyped-def]
#         def publish(self, msg):
#         ^
# patterns/behavioral/publish_subscribe.py:38: error: Function is missing a type
# annotation  [no-untyped-def]
#         def __init__(self, name, msg_center):
#         ^
# patterns/behavioral/publish_subscribe.py:42: error: Function is missing a type
# annotation  [no-untyped-def]
#         def subscribe(self, msg):
#         ^
# patterns/behavioral/publish_subscribe.py:45: error: Function is missing a type
# annotation  [no-untyped-def]
#         def unsubscribe(self, msg):
#         ^
# patterns/behavioral/publish_subscribe.py:48: error: Function is missing a type
# annotation  [no-untyped-def]
#         def run(self, msg):
#         ^
# patterns/behavioral/publish_subscribe.py:52: error: Function is missing a
# return type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/publish_subscribe.py:52: note: Use "-> None" if function does not return a value
# patterns/behavioral/observer.py:68: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/observer.py:68: note: Use "-> None" if function does not return a value
# patterns/behavioral/memento.py:12: error: Function is missing a type annotation
#  [no-untyped-def]
#     def memento(obj, deep=False):
#     ^
# patterns/behavioral/memento.py:15: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def restore():
#         ^
# patterns/behavioral/memento.py:15: note: Use "-> None" if function does not return a value
# patterns/behavioral/memento.py:31: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __init__(self, deep, *targets):
#         ^
# patterns/behavioral/memento.py:34: error: Call to untyped function "commit" in
# typed context  [no-untyped-call]
#             self.commit()
#             ^
# patterns/behavioral/memento.py:36: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def commit(self):
#         ^
# patterns/behavioral/memento.py:36: note: Use "-> None" if function does not return a value
# patterns/behavioral/memento.py:37: error: Call to untyped function "memento" in
# typed context  [no-untyped-call]
#             self.states = [memento(target, self.deep) for target in self.t...
#                            ^
# patterns/behavioral/memento.py:39: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def rollback(self):
#         ^
# patterns/behavioral/memento.py:39: note: Use "-> None" if function does not return a value
# patterns/behavioral/memento.py:50: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __init__(self, method):
#         ^
# patterns/behavioral/memento.py:53: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __get__(self, obj, T):
#         ^
# patterns/behavioral/memento.py:60: error: Function is missing a type annotation
#  [no-untyped-def]
#             def transaction(*args, **kwargs):
#             ^
# patterns/behavioral/memento.py:61: error: Call to untyped function "memento" in
# typed context  [no-untyped-call]
#                 state = memento(obj)
#                         ^
# patterns/behavioral/memento.py:72: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __init__(self, value):
#         ^
# patterns/behavioral/memento.py:75: error: Function is missing a type annotation
#  [no-untyped-def]
#         def __repr__(self):
#         ^
# patterns/behavioral/memento.py:78: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def increment(self):
#         ^
# patterns/behavioral/memento.py:78: note: Use "-> None" if function does not return a value
# patterns/behavioral/memento.py:82: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def do_stuff(self):
#         ^
# patterns/behavioral/memento.py:82: note: Use "-> None" if function does not return a value
# patterns/behavioral/memento.py:84: error: Call to untyped function "increment"
# in typed context  [no-untyped-call]
#             self.increment()  # <- will fail and rollback
#             ^
# patterns/behavioral/memento.py:87: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/memento.py:87: note: Use "-> None" if function does not return a value
# patterns/behavioral/mediator.py:35: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/mediator.py:35: note: Use "-> None" if function does not return a value
# patterns/behavioral/iterator_alt.py:39: error: Function is missing a return
# type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/iterator_alt.py:39: note: Use "-> None" if function does not return a value
# patterns/behavioral/iterator.py:10: error: Function is missing a type
# annotation  [no-untyped-def]
#     def count_to(count):
#     ^
# patterns/behavioral/iterator.py:18: error: Call to untyped function "count_to"
# in typed context  [no-untyped-call]
#         return count_to(2)
#                ^
# patterns/behavioral/iterator.py:22: error: Call to untyped function "count_to"
# in typed context  [no-untyped-call]
#         return count_to(5)
#                ^
# patterns/behavioral/iterator.py:25: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/iterator.py:25: note: Use "-> None" if function does not return a value
# patterns/behavioral/command.py:77: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/command.py:77: note: Use "-> None" if function does not return a value
# patterns/behavioral/chaining_method.py:26: error: Function is missing a return
# type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/chaining_method.py:26: note: Use "-> None" if function does not return a value
# patterns/behavioral/chain_of_responsibility.py:93: error: Function is missing a
# return type annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/chain_of_responsibility.py:93: note: Use "-> None" if function does not return a value
# patterns/behavioral/catalog.py:80: error: Unused "type: ignore" comment
#             self._instance_method_choices[self.param].__get__(self)()  # t...
#             ^
# patterns/behavioral/catalog.py:114: error: Function is missing a return type
# annotation  [no-untyped-def]
#         def main_method(self):
#         ^
# patterns/behavioral/catalog.py:114: note: Use "-> None" if function does not return a value
# patterns/behavioral/catalog.py:119: error: Unused "type: ignore" comment
#             self._class_method_choices[self.param].__get__(None, self.__cl...
#             ^
# patterns/behavioral/catalog.py:156: error: Unused "type: ignore" comment
#             self._static_method_choices[self.param].__get__(None, self.__c...
#             ^
# patterns/behavioral/catalog.py:160: error: Function is missing a return type
# annotation  [no-untyped-def]
#     def main():
#     ^
# patterns/behavioral/catalog.py:160: note: Use "-> None" if function does not return a value
# Found 316 errors in 38 files (checked 46 source files)

# %%
# mypy --config-file mypy_full_check.ini -p tests ~~~~~~~~~~~~~~~~~~~~~~~
! cd .. && mypy --config-file mypy_full_check.ini -p tests
# Out:
# tests/test_hsm.py:17: error: Function is missing a return type annotation
# [no-untyped-def]
#         def setUpClass(cls):
#         ^
# tests/test_hsm.py:17: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:18: error: "Type[HsmMethodTest]" has no attribute "hsm"
# [attr-defined]
#             cls.hsm = HierachicalStateMachine()
#             ^
# tests/test_hsm.py:18: error: Call to untyped function "HierachicalStateMachine"
# in typed context  [no-untyped-call]
#             cls.hsm = HierachicalStateMachine()
#                       ^
# tests/test_hsm.py:20: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_initial_state_shall_be_standby(cls):
#         ^
# tests/test_hsm.py:20: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:21: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Standby), T...
#                                        ^
# tests/test_hsm.py:23: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_unsupported_state_shall_raise_exception(cls):
#         ^
# tests/test_hsm.py:23: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:25: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm._next_state("missing")
#                 ^
# tests/test_hsm.py:27: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_unsupported_message_type_shall_raise_exception(cls):
#         ^
# tests/test_hsm.py:27: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:29: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm.on_message("trigger")
#                 ^
# tests/test_hsm.py:31: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_calling_next_state_shall_change_current_state(cls):
#         ^
# tests/test_hsm.py:31: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:32: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#             cls.hsm._current_state = Standby  # initial state
#             ^
# tests/test_hsm.py:33: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#             cls.hsm._next_state("active")
#             ^
# tests/test_hsm.py:34: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Active), Tr...
#                                        ^
# tests/test_hsm.py:35: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#             cls.hsm._current_state = Standby(cls.hsm)  # initial state
#             ^
# tests/test_hsm.py:35: error: Call to untyped function "Standby" in typed
# context  [no-untyped-call]
#             cls.hsm._current_state = Standby(cls.hsm)  # initial state
#                                      ^
# tests/test_hsm.py:37: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_method_perform_switchover_shall_return_specifically(cls):
#         ^
# tests/test_hsm.py:37: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:40: error: "HsmMethodTest" has no attribute "hsm"
# [attr-defined]
#             return_value = cls.hsm._perform_switchover()
#                            ^
# tests/test_hsm.py:50: error: Function is missing a return type annotation
# [no-untyped-def]
#         def setUpClass(cls):
#         ^
# tests/test_hsm.py:50: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:51: error: "Type[StandbyStateTest]" has no attribute "hsm"
# [attr-defined]
#             cls.hsm = HierachicalStateMachine()
#             ^
# tests/test_hsm.py:51: error: Call to untyped function "HierachicalStateMachine"
# in typed context  [no-untyped-call]
#             cls.hsm = HierachicalStateMachine()
#                       ^
# tests/test_hsm.py:53: error: Function is missing a return type annotation
# [no-untyped-def]
#         def setUp(cls):
#         ^
# tests/test_hsm.py:53: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:54: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.hsm._current_state = Standby(cls.hsm)
#             ^
# tests/test_hsm.py:54: error: Call to untyped function "Standby" in typed
# context  [no-untyped-call]
#             cls.hsm._current_state = Standby(cls.hsm)
#                                      ^
# tests/test_hsm.py:56: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_given_standby_on_message_switchover_shall_set_active(cls)...
#         ^
# tests/test_hsm.py:56: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:57: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.hsm.on_message("switchover")
#             ^
# tests/test_hsm.py:58: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Active), Tr...
#                                        ^
# tests/test_hsm.py:60: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_given_standby_on_message_switchover_shall_call_hsm_method...
#         ^
# tests/test_hsm.py:60: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:62: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm, "_perform_switchover"
#                 ^
# tests/test_hsm.py:64: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm, "_check_mate_status"
#                 ^
# tests/test_hsm.py:66: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm, "_send_switchover_response"
#                 ^
# tests/test_hsm.py:68: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm, "_next_state"
#                 ^
# tests/test_hsm.py:70: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm.on_message("switchover")
#                 ^
# tests/test_hsm.py:76: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_given_standby_on_message_fault_trigger_shall_set_suspect(...
#         ^
# tests/test_hsm.py:76: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:77: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.hsm.on_message("fault trigger")
#             ^
# tests/test_hsm.py:78: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Suspect), T...
#                                        ^
# tests/test_hsm.py:80: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_given_standby_on_message_diagnostics_failed_shall_raise_e...
#         ^
# tests/test_hsm.py:80: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:84: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm.on_message("diagnostics failed")
#                 ^
# tests/test_hsm.py:85: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Standby), T...
#                                        ^
# tests/test_hsm.py:87: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_given_standby_on_message_diagnostics_passed_shall_raise_e...
#         ^
# tests/test_hsm.py:87: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:91: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm.on_message("diagnostics passed")
#                 ^
# tests/test_hsm.py:92: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Standby), T...
#                                        ^
# tests/test_hsm.py:94: error: Function is missing a return type annotation
# [no-untyped-def]
#         def test_given_standby_on_message_operator_inservice_shall_raise_e...
#         ^
# tests/test_hsm.py:94: note: Use "-> None" if function does not return a value
# tests/test_hsm.py:98: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#                 cls.hsm.on_message("operator inservice")
#                 ^
# tests/test_hsm.py:99: error: "StandbyStateTest" has no attribute "hsm"
# [attr-defined]
#             cls.assertEqual(isinstance(cls.hsm._current_state, Standby), T...
#                                        ^
# Found 44 errors in 1 file (checked 2 source files)

# %% [markdown]
# ---
#
# ## [`tox.ini`](../tox.ini)
#
# OK, if everything in the above testing is 'good' then your ready to run a full tox matrix.
#
# >Note: The full `tox` matrix run is very slow so only run it when you are ready to push changes to the repository.

# %%
if True:  # set to True when your ready
    is_recreate_tox = True  # set to True to force recreation of tox environments
    if is_recreate_tox:
        # force recreation of virtual environments (-r or --recreate)
        ! cd .. && sudo tox -r > tox_run_r.md
    else:
        # use existing virtual environment (only build if not present)
        ! cd .. && sudo tox > tox_run.md

# %% [markdown]
# ---
